# %%
from profile_processing import ProfileProcessor

pp = ProfileProcessor(memory_path='memory_profiler_results.txt',
                      line_path='line_profiler_results.txt')
pp.plot_both(xtick_style='dense')
